# %%
from qiskit import QuantumCircuit, transpile, QuantumRegister, ClassicalRegister
from qiskit.circuit import Gate

qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.h(qreg_q[0])
circuit.h(qreg_q[2])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[4])
circuit.append(Gate(name=r'Undo Error', num_qubits=3, params=[]), [[0], [1], [2]])
circuit.measure(qreg_q[4], creg_c[3])
circuit.measure(qreg_q[3], creg_c[3])
circuit.h(qreg_q[0])
circuit.h(qreg_q[2])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])


circuit.draw('mpl')

# %%
transpiled_circuit = transpile(circuit, basis_gates=['id', 'x', 'y', 'z', 'h', 'cz'])
print("\nTranspiled Circuit:")
transpiled_circuit.draw('mpl')
# Out:
# Transpiled Circuit:

# %%
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[2])
circuit.h(qreg_q[1])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.cz(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[1])
circuit.cz(qreg_q[0], qreg_q[2])
circuit.h(qreg_q[2])
circuit.cz(qreg_q[0], qreg_q[3])
circuit.cz(qreg_q[1], qreg_q[3])
circuit.h(qreg_q[3])
circuit.cz(qreg_q[1], qreg_q[4])
circuit.cz(qreg_q[2], qreg_q[4])
circuit.h(qreg_q[4])
circuit.append(Gate(name=r'Undo Error', num_qubits=3, params=[]), [[0], [1], [2]])
circuit.measure(qreg_q[4], creg_c[3])
circuit.measure(qreg_q[3], creg_c[3])
circuit.h(qreg_q[0])
circuit.cz(qreg_q[0], qreg_q[2])
circuit.cz(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[1])

circuit.draw('mpl')
