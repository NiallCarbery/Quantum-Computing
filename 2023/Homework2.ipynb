# %% [markdown]
# ##Question 1)
# The electron in the infinite well with the three quantum states given by formulae (1)-(3):
# - The electron is in a superposition state (1/
# √
# 3)ψ1 + (1/
# √
# 3)ψ2 + (1/
# √
# 3)ψ3. <b>What is the expected
# value of the energy of the particle?</b>
# <p>
# - The electron is in a superposition state (1/
# √
# 2)ψ1 + (1/
# √
# 2)ψ3. <b>What is the expected value of the
# momentum of the particle?</b>
#
# ![CamScanner 10-02-2023 19.39(1)_1.jpg](data:image/jpeg;base64,...)![CamScanner 10-02-2023 19.39(1)_2.jpg](data:image/jpeg;base64,...)
#
# ##Answer:
#
# - Expected value of of energy of particle: 7.021 ev
#
# - Expected value of momentum of particle: 0

# %% [markdown]
# ## Question 2)
# The particle in the double-well:
# - Assume that we can attach
# a measurement apparatus to this “double-well” system.
# - At any given instance of time, we can activate
# the measurement device and it will simply determine whether or not the particle is the left potential
# well.
# - Can this system be used as a qubit? If yes, how would you define quantum states |0⟩ and |1⟩?
# - What measurement outcomes would you associate with |0⟩ and |1⟩ respectively?
# - What could be a
# superposition state?
# - How would you see it in measurement?

# %% [markdown]
# Yes this system can be used as a quibit,
# - the quantum state |0⟩ would be defined as the left well and the right well as |1⟩
# - the states could be switched as there picked abritarily.
# -Measurement of the particle in left well by the measurement appartus would mean state |0⟩
# -Measurement of the particle not in the left well would imply that its in state |1⟩ in the right well
#
# <p>
# The superposition state would be defined as the state of the particle in the double well as we don't know which well the particle is in without measurement. We can only repersent it as the comination of proabilities that it could be in either well. The superposition state would be seen in the measurement by measuring the particle multiple times to find the probabilties of finding particle in either well. The probabilities would be combined to find the superposition state.
