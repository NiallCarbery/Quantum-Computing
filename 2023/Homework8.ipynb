# %% [markdown]
# ## Question 1
# A two-qubit system is described by the following state |ψ⟩ = i√3/2√2|00⟩ + i/2√2 |01⟩ + √3/2√2
# |10⟩ + 1/2√2 |11⟩.
# Is this a valid state? Is this a separable or entangled state? If the state is separable, what are its
# corresponding single-qubit states.
# ![Q1.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 2
# Two qubits, each initially in the states |ψ1⟩ = 1/√2
# |0⟩ + 1/√2
# |1⟩ and |ψ2⟩ = |0⟩ respectively, interact and
# experience a dynamical evolution. As a result of this interaction, they are subject to the evolution
# operator:
# ![CamScanner 11-09-2023 16.17_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question 3
# A two-qubit system is described by the following state |ψ⟩ = i√3/2√2|00⟩ + i/2√2 |01⟩ + √3/2√2
# (as in Problem 1 of this Homework Assignment). Construct the project to project on the state |1⟩ of
# the second qubit. What is the matrix form of this operator? Apply this projector to the state |ψ⟩:
# what is the resulting state of qubit 1 and qubit 2? Are they staying in superposition or not? Was the
# state separable of entangled?
#
# ![CamScanner 11-09-2023 19.04_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 11-09-2023 19.04_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question 4
# A two-qubit system is described by the Bell state |Ψ−⟩ = 1/√2 (|01⟩ − |10⟩). Construct the project to
# project on the state |0⟩ of the second qubit. What is the matrix form of this operator? Apply this
# projector to the state |Ψ−⟩: What is the resulting state of qubit 1 and qubit 2? Do they stay in
# superposition or not? Is the state separable of entangled?

# %% [markdown]
# ![CamScanner 11-09-2023 19.41_1.jpg](data:image/jpeg;base64,...)
